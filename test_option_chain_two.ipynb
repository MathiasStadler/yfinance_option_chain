# %% [markdown]
# # [from here](https://aroussi.com/post/download-options-data)
#
# # [](https://github.com/ranaroussi/yfinance)

# %%
import yfinance as yf
aapl = yf.Ticker("TREX")
aapl.info
hist = aapl.history(period="max")
hist.head()
# Out:
#                                Open      High       Low     Close   Volume  \
# Date
# 1999-04-08 00:00:00-04:00  1.250000  1.562500  1.250000  1.421875  7154400
# 1999-04-09 00:00:00-04:00  1.531250  1.734375  1.507813  1.609375  2672800
# 1999-04-12 00:00:00-04:00  1.625000  1.703125  1.570313  1.625000  1526400
# 1999-04-13 00:00:00-04:00  1.664063  1.765625  1.632813  1.718750   512000
# 1999-04-14 00:00:00-04:00  1.726563  1.742188  1.625000  1.710938   900000
#
#                            Dividends  Stock Splits
# Date
# 1999-04-08 00:00:00-04:00        0.0           0.0
# 1999-04-09 00:00:00-04:00        0.0           0.0
# 1999-04-12 00:00:00-04:00        0.0           0.0
# 1999-04-13 00:00:00-04:00        0.0           0.0
# 1999-04-14 00:00:00-04:00        0.0           0.0

# %%
aapl.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 2014-05-08 00:00:00-04:00        0.0           2.0
# 2018-06-19 00:00:00-04:00        0.0           2.0
# 2020-09-15 00:00:00-04:00        0.0           2.0

# %%
aapl.dividends
# Out:
# Series([], Name: Dividends, dtype: float64)

# %%
aapl.financials
# Out:
#                                                       2023-12-31  \
# Tax Effect Of Unusual Items                                  0.0
# Tax Rate For Calcs                                         0.256
# Normalized EBITDA                                    326393000.0
# Total Unusual Items                                          0.0
# Total Unusual Items Excluding Goodwill                       0.0
# Net Income From Continuing Operation Net Minori...   205384000.0
# Reconciled Depreciation                               50189000.0
# Reconciled Cost Of Revenue                           642430000.0
# EBITDA                                               326393000.0
# EBIT                                                 276204000.0
# Net Interest Income                                      -5000.0
# Interest Income                                              NaN
# Normalized Income                                    205384000.0
# ...

# %%
aapl.balance_sheet
# Out:
#                                                    2023-12-31   2022-12-31  \
# Treasury Shares Number                             32363306.0   32098410.0
# Ordinary Shares Number                            108611537.0  108743423.0
# Share Issued                                      140974843.0  140841833.0
# Net Debt                                            3541000.0  209675000.0
# Total Debt                                         32003000.0  253462000.0
# ...                                                       ...          ...
# Other Receivables                                         NaN          NaN
# Taxes Receivable                                    9611000.0   23979000.0
# Accounts Receivable                                41136000.0   98057000.0
# Cash Cash Equivalents And Short Term Investments    1959000.0   12325000.0
# Cash And Cash Equivalents                           1959000.0   12325000.0
#
# ...

# %%
aapl.cashflow
# Out:
#                                                  2023-12-31   2022-12-31  \
# Free Cash Flow                                  223331000.0   39992000.0
# Repurchase Of Capital Stock                     -18450000.0 -398382000.0
# Repayment Of Debt                              -810000000.0 -203000000.0
# Issuance Of Debt                                593500000.0  425000000.0
# Capital Expenditure                            -166089000.0 -176228000.0
# Interest Paid Supplemental Data                     51000.0          0.0
# Income Tax Paid Supplemental Data                52340000.0   59934000.0
# End Cash Position                                 1959000.0   12325000.0
# Beginning Cash Position                          12325000.0  141053000.0
# Changes In Cash                                 -10366000.0 -128728000.0
# Financing Cash Flow                            -233697000.0 -176064000.0
# Cash Flow From Continuing Financing Activities -233697000.0 -176064000.0
# ...

# %%
aapl.options
# Out:
# ('2024-11-15', '2024-12-20', '2025-01-17', '2025-04-17')

# %%
opt = aapl.option_chain('2024-11-15')
# opt.calls
opt.puts
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice  bid  ask  \
# 0  TREX241115P00040000 2024-10-18 15:11:39+00:00    40.0       0.05  0.0  0.0
# 1  TREX241115P00050000 2024-10-22 13:42:23+00:00    50.0       0.40  0.0  0.0
# 2  TREX241115P00055000 2024-10-23 13:30:04+00:00    55.0       0.85  0.0  0.0
# 3  TREX241115P00057500 2024-10-24 19:57:46+00:00    57.5       1.40  0.0  0.0
# 4  TREX241115P00060000 2024-10-24 19:57:09+00:00    60.0       2.05  0.0  0.0
# 5  TREX241115P00062500 2024-10-24 15:49:38+00:00    62.5       3.00  0.0  0.0
# 6  TREX241115P00065000 2024-10-23 14:04:49+00:00    65.0       3.85  0.0  0.0
# 7  TREX241115P00067500 2024-10-16 17:33:06+00:00    67.5       4.90  0.0  0.0
# 8  TREX241115P00070000 2024-10-17 19:53:12+00:00    70.0       7.60  0.0  0.0
#
#    change  percentChange  volume  openInterest  impliedVolatility  inTheMoney  \
# 0     0.0            0.0     1.0             1           0.500005       False
# ...
